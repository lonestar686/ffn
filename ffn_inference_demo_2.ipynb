# %%
from google.protobuf import text_format
from ffn.inference import inference
from ffn.inference import inference_pb2
# Out:
# /wg/common/UTILITYSUITE/apps/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import logging
logging.basicConfig(level=logging.INFO)
# for gpu
import os
os.environ["CUDA_VISIBLE_DEVICES"]='3'

# %%
config = '''image {
  hdf5: "third_party/neuroproof_examples/training_sample2/grayscale_maps.h5:raw"
}
image_mean: 128
image_stddev: 33
checkpoint_interval: 1800
seed_policy: "PolicyPeaks"
model_checkpoint_path: "models/fib25/model.ckpt-27465036"
model_name: "convstack_3d.ConvStack3DFFNModel"
model_args: "{\\"depth\\": 12, \\"fov_size\\": [33, 33, 33], \\"deltas\\": [8, 8, 8]}"
segmentation_output_dir: "results/fib25/training2"
inference_options {
  init_activation: 0.95
  pad_value: 0.05
  move_threshold: 0.9
  min_boundary_dist { x: 1 y: 1 z: 1}
  segment_threshold: 0.6
  min_segment_size: 1000
}'''
req = inference_pb2.InferenceRequest()
_ = text_format.Parse(config, req)

# %%
runner = inference.Runner()
runner.start(req)
# Out:
# INFO:root:Available TF devices: [_DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456), _DeviceAttributes(/job:localhost/replica:0/task:0/device:GPU:0, GPU, 15857916314)]
# INFO:root:Importing symbol ConvStack3DFFNModel from ffn.training.models.convstack_3d
# INFO:root:Loading checkpoint.
# INFO:tensorflow:Restoring parameters from models/fib25/model.ckpt-27465036
# INFO:tensorflow:Restoring parameters from models/fib25/model.ckpt-27465036
# INFO:root:Checkpoint loaded.
# INFO:root:Executor starting.

# %%
# Create the whole segments
runner.run((0,0,0), (250, 250, 250))
# Out:
# INFO:root:Process subvolume: (0, 0, 0)
# INFO:root:Requested bounds are (0, 0, 0) + (250, 250, 250)
# INFO:root:Destination bounds are (0, 0, 0) + (250, 250, 250)
# INFO:root:Fetch bounds are array([0, 0, 0]) + array([250, 250, 250])
# INFO:root:Fetched image of size (250, 250, 250) prior to transform
# INFO:root:Image data loaded, shape: (250, 250, 250).
# INFO:root:Registered as client 0.
# INFO:root:client 0 starting
# INFO:root:peaks: starting
# INFO:root:peaks: filtering done
# INFO:root:peaks: edt done
# INFO:root:peaks: found 17524 local maxima
# INFO:root:[cl 0] Starting segmentation at (16, 18, 109) (zyx)
# /wgdisk/st0008/hzh/workspace/ffn/ffn/inference/inference.py:627: RuntimeWarning: invalid value encountered in greater_equal
#   mask = self.seed[sel] >= self.options.segment_threshold
# INFO:root:[cl 0] Created supervoxel:1  seed(zyx):(16, 18, 109)  size:1097342  iters:1884
# INFO:root:[cl 0] Starting segmentation at (16, 19, 228) (zyx)
# INFO:root:[cl 0] Created supervoxel:2  seed(zyx):(16, 19, 228)  size:25434  iters:7
# INFO:root:[cl 0] Starting segmentation at (16, 24, 204) (zyx)
# INFO:root:[cl 0] Created supervoxel:3  seed(zyx):(16, 24, 204)  size:1757  iters:1
# INFO:root:[cl 0] Starting segmentation at (16, 41, 181) (zyx)
# INFO:root:[cl 0] Created supervoxel:4  seed(zyx):(16, 41, 181)  size:1086990  iters:1789
# INFO:root:[cl 0] Starting segmentation at (16, 43, 231) (zyx)
# INFO:root:[cl 0] Created supervoxel:5  seed(zyx):(16, 43, 231)  size:52429  iters:49
# INFO:root:[cl 0] Starting segmentation at (16, 54, 71) (zyx)
# INFO:root:[cl 0] Created supervoxel:6  seed(zyx):(16, 54, 71)  size:368900  iters:1022
# INFO:root:[cl 0] Starting segmentation at (16, 56, 145) (zyx)
# INFO:root:[cl 0] Created supervoxel:7  seed(zyx):(16, 56, 145)  size:4986  iters:8
# INFO:root:[cl 0] Starting segmentation at (16, 80, 207) (zyx)
# INFO:root:[cl 0] Created supervoxel:8  seed(zyx):(16, 80, 207)  size:858336  iters:1760
# INFO:root:[cl 0] Starting segmentation at (16, 91, 52) (zyx)
# INFO:root:[cl 0] Created supervoxel:9  seed(zyx):(16, 91, 52)  size:303131  iters:459
# INFO:root:[cl 0] Starting segmentation at (16, 118, 128) (zyx)
# INFO:root:[cl 0] Created supervoxel:10  seed(zyx):(16, 118, 128)  size:2979  iters:11
# INFO:root:[cl 0] Starting segmentation at (16, 137, 114) (zyx)
# INFO:root:[cl 0] Created supervoxel:11  seed(zyx):(16, 137, 114)  size:273187  iters:402
# INFO:root:[cl 0] Starting segmentation at (16, 166, 195) (zyx)
# INFO:root:[cl 0] Created supervoxel:12  seed(zyx):(16, 166, 195)  size:21241  iters:23
# INFO:root:[cl 0] Starting segmentation at (16, 180, 169) (zyx)
# INFO:root:[cl 0] Created supervoxel:13  seed(zyx):(16, 180, 169)  size:942443  iters:1168
# INFO:root:[cl 0] Starting segmentation at (16, 190, 52) (zyx)
# INFO:root:[cl 0] Created supervoxel:14  seed(zyx):(16, 190, 52)  size:751089  iters:1423
# INFO:root:[cl 0] Starting segmentation at (17, 132, 175) (zyx)
# INFO:root:[cl 0] Created supervoxel:15  seed(zyx):(17, 132, 175)  size:2166  iters:7
# INFO:root:[cl 0] Starting segmentation at (17, 148, 73) (zyx)
# INFO:root:[cl 0] Created supervoxel:16  seed(zyx):(17, 148, 73)  size:2420  iters:3
# INFO:root:[cl 0] Starting segmentation at (17, 154, 205) (zyx)
# INFO:root:[cl 0] Created supervoxel:17  seed(zyx):(17, 154, 205)  size:4275  iters:7
# INFO:root:[cl 0] Starting segmentation at (17, 209, 231) (zyx)
# INFO:root:[cl 0] Created supervoxel:18  seed(zyx):(17, 209, 231)  size:1968  iters:1
# INFO:root:[cl 0] Starting segmentation at (17, 225, 83) (zyx)
# INFO:root:[cl 0] Created supervoxel:19  seed(zyx):(17, 225, 83)  size:12228  iters:20
# INFO:root:[cl 0] Starting segmentation at (18, 88, 155) (zyx)
# INFO:root:[cl 0] Created supervoxel:20  seed(zyx):(18, 88, 155)  size:12227  iters:29
# INFO:root:[cl 0] Starting segmentation at (18, 145, 88) (zyx)
# INFO:root:[cl 0] Created supervoxel:21  seed(zyx):(18, 145, 88)  size:3020  iters:1
# INFO:root:[cl 0] Starting segmentation at (18, 193, 80) (zyx)
# INFO:root:[cl 0] Created supervoxel:22  seed(zyx):(18, 193, 80)  size:283643  iters:902
# INFO:root:[cl 0] Starting segmentation at (18, 208, 111) (zyx)
# INFO:root:[cl 0] Created supervoxel:23  seed(zyx):(18, 208, 111)  size:2143  iters:1
# INFO:root:[cl 0] Starting segmentation at (18, 223, 67) (zyx)
# INFO:root:[cl 0] Created supervoxel:24  seed(zyx):(18, 223, 67)  size:275742  iters:542
# INFO:root:[cl 0] Starting segmentation at (18, 232, 42) (zyx)
# INFO:root:[cl 0] Created supervoxel:25  seed(zyx):(18, 232, 42)  size:4174  iters:1
# INFO:root:[cl 0] Starting segmentation at (19, 78, 139) (zyx)
# INFO:root:[cl 0] Created supervoxel:26  seed(zyx):(19, 78, 139)  size:4160  iters:14
# INFO:root:[cl 0] Starting segmentation at (19, 107, 71) (zyx)
# INFO:root:[cl 0] Created supervoxel:27  seed(zyx):(19, 107, 71)  size:5630  iters:25
# INFO:root:[cl 0] Starting segmentation at (19, 232, 225) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (20, 191, 226) (zyx)
# INFO:root:[cl 0] Created supervoxel:28  seed(zyx):(20, 191, 226)  size:9093  iters:8
# INFO:root:[cl 0] Starting segmentation at (21, 118, 156) (zyx)
# INFO:root:[cl 0] Created supervoxel:29  seed(zyx):(21, 118, 156)  size:25770  iters:92
# INFO:root:[cl 0] Starting segmentation at (22, 139, 161) (zyx)
# INFO:root:[cl 0] Created supervoxel:30  seed(zyx):(22, 139, 161)  size:1307  iters:1
# INFO:root:[cl 0] Starting segmentation at (22, 179, 77) (zyx)
# INFO:root:[cl 0] Created supervoxel:31  seed(zyx):(22, 179, 77)  size:14231  iters:59
# INFO:root:[cl 0] Starting segmentation at (22, 186, 129) (zyx)
# INFO:root:[cl 0] Failed: too small: 579
# INFO:root:[cl 0] Starting segmentation at (23, 164, 94) (zyx)
# INFO:root:[cl 0] Failed: too small: 620
# INFO:root:[cl 0] Starting segmentation at (23, 230, 93) (zyx)
# INFO:root:[cl 0] Created supervoxel:32  seed(zyx):(23, 230, 93)  size:6882  iters:7
# INFO:root:[cl 0] Starting segmentation at (26, 162, 175) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (26, 215, 132) (zyx)
# INFO:root:[cl 0] Created supervoxel:33  seed(zyx):(26, 215, 132)  size:15922  iters:54
# INFO:root:[cl 0] Starting segmentation at (27, 112, 97) (zyx)
# INFO:root:[cl 0] Created supervoxel:34  seed(zyx):(27, 112, 97)  size:5590  iters:21
# INFO:root:[cl 0] Starting segmentation at (27, 140, 169) (zyx)
# INFO:root:[cl 0] Created supervoxel:35  seed(zyx):(27, 140, 169)  size:23611  iters:81
# INFO:root:[cl 0] Starting segmentation at (27, 163, 96) (zyx)
# INFO:root:[cl 0] Failed: too small: 500
# INFO:root:[cl 0] Starting segmentation at (28, 137, 183) (zyx)
# INFO:root:[cl 0] Created supervoxel:36  seed(zyx):(28, 137, 183)  size:1005  iters:2
# INFO:root:[cl 0] Starting segmentation at (29, 187, 135) (zyx)
# INFO:root:[cl 0] Created supervoxel:37  seed(zyx):(29, 187, 135)  size:6510  iters:38
# INFO:root:[cl 0] Starting segmentation at (29, 221, 233) (zyx)
# INFO:root:[cl 0] Failed: too small: 432
# INFO:root:[cl 0] Starting segmentation at (30, 218, 105) (zyx)
# INFO:root:[cl 0] Created supervoxel:38  seed(zyx):(30, 218, 105)  size:1620  iters:9
# INFO:root:[cl 0] Starting segmentation at (30, 230, 104) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (31, 120, 94) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (31, 122, 176) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (31, 137, 155) (zyx)
# INFO:root:[cl 0] Failed: too small: 547
# INFO:root:[cl 0] Starting segmentation at (31, 233, 98) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (32, 35, 161) (zyx)
# INFO:root:[cl 0] Failed: too small: 582
# INFO:root:[cl 0] Starting segmentation at (32, 126, 95) (zyx)
# INFO:root:[cl 0] Failed: too small: 575
# INFO:root:[cl 0] Starting segmentation at (32, 132, 152) (zyx)
# INFO:root:[cl 0] Failed: too small: 161
# INFO:root:[cl 0] Starting segmentation at (33, 29, 154) (zyx)
# INFO:root:[cl 0] Created supervoxel:39  seed(zyx):(33, 29, 154)  size:21680  iters:67
# INFO:root:[cl 0] Starting segmentation at (34, 29, 22) (zyx)
# INFO:root:[cl 0] Created supervoxel:40  seed(zyx):(34, 29, 22)  size:8884  iters:24
# INFO:root:[cl 0] Starting segmentation at (34, 131, 146) (zyx)
# INFO:root:[cl 0] Failed: too small: 277
# INFO:root:[cl 0] Starting segmentation at (34, 163, 105) (zyx)
# INFO:root:[cl 0] Created supervoxel:41  seed(zyx):(34, 163, 105)  size:2236  iters:2
# INFO:root:[cl 0] Starting segmentation at (35, 125, 45) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (36, 129, 94) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (36, 231, 230) (zyx)
# INFO:root:[cl 0] Failed: too small: 917
# INFO:root:[cl 0] Starting segmentation at (37, 62, 114) (zyx)
# INFO:root:[cl 0] Created supervoxel:42  seed(zyx):(37, 62, 114)  size:14705  iters:50
# INFO:root:[cl 0] Starting segmentation at (37, 102, 115) (zyx)
# INFO:root:[cl 0] Failed: too small: 454
# INFO:root:[cl 0] Starting segmentation at (37, 134, 141) (zyx)
# INFO:root:[cl 0] Created supervoxel:43  seed(zyx):(37, 134, 141)  size:1686  iters:1
# INFO:root:[cl 0] Starting segmentation at (37, 230, 117) (zyx)
# INFO:root:[cl 0] Failed: too small: 760
# INFO:root:[cl 0] Starting segmentation at (38, 92, 147) (zyx)
# INFO:root:[cl 0] Failed: too small: 490
# INFO:root:[cl 0] Starting segmentation at (38, 156, 147) (zyx)
# INFO:root:[cl 0] Created supervoxel:44  seed(zyx):(38, 156, 147)  size:3168  iters:1
# INFO:root:[cl 0] Starting segmentation at (39, 97, 116) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (39, 107, 91) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (40, 39, 170) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (40, 100, 128) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (41, 182, 153) (zyx)
# INFO:root:[cl 0] Failed: too small: 513
# INFO:root:[cl 0] Starting segmentation at (41, 186, 147) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (42, 229, 63) (zyx)
# INFO:root:[cl 0] Created supervoxel:45  seed(zyx):(42, 229, 63)  size:1393  iters:1
# INFO:root:[cl 0] Starting segmentation at (43, 50, 186) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (43, 75, 152) (zyx)
# INFO:root:[cl 0] Failed: too small: 794
# INFO:root:[cl 0] Starting segmentation at (43, 78, 100) (zyx)
# INFO:root:[cl 0] Created supervoxel:46  seed(zyx):(43, 78, 100)  size:21015  iters:91
# INFO:root:[cl 0] Starting segmentation at (43, 175, 100) (zyx)
# INFO:root:[cl 0] Created supervoxel:47  seed(zyx):(43, 175, 100)  size:1053  iters:1
# INFO:root:[cl 0] Starting segmentation at (44, 44, 166) (zyx)
# INFO:root:[cl 0] Created supervoxel:48  seed(zyx):(44, 44, 166)  size:11633  iters:45
# INFO:root:[cl 0] Starting segmentation at (46, 88, 92) (zyx)
# INFO:root:[cl 0] Created supervoxel:49  seed(zyx):(46, 88, 92)  size:9137  iters:44
# INFO:root:[cl 0] Starting segmentation at (48, 73, 30) (zyx)
# INFO:root:[cl 0] Failed: too small: 293
# INFO:root:[cl 0] Starting segmentation at (51, 82, 84) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (51, 111, 107) (zyx)
# INFO:root:[cl 0] Failed: too small: 393
# INFO:root:[cl 0] Starting segmentation at (51, 124, 89) (zyx)
# INFO:root:[cl 0] Failed: too small: 525
# INFO:root:[cl 0] Starting segmentation at (51, 229, 195) (zyx)
# INFO:root:[cl 0] Created supervoxel:50  seed(zyx):(51, 229, 195)  size:11126  iters:24
# INFO:root:[cl 0] Starting segmentation at (52, 75, 150) (zyx)
# INFO:root:[cl 0] Created supervoxel:51  seed(zyx):(52, 75, 150)  size:1416  iters:1
# INFO:root:[cl 0] Starting segmentation at (52, 86, 83) (zyx)
# INFO:root:[cl 0] Failed: too small: 311
# INFO:root:[cl 0] Starting segmentation at (52, 229, 230) (zyx)
# INFO:root:[cl 0] Created supervoxel:52  seed(zyx):(52, 229, 230)  size:9403  iters:8
# INFO:root:[cl 0] Starting segmentation at (53, 74, 90) (zyx)
# INFO:root:[cl 0] Created supervoxel:53  seed(zyx):(53, 74, 90)  size:1836  iters:1
# INFO:root:[cl 0] Starting segmentation at (53, 106, 99) (zyx)
# INFO:root:[cl 0] Failed: too small: 795
# INFO:root:[cl 0] Starting segmentation at (53, 113, 127) (zyx)
# INFO:root:[cl 0] Failed: too small: 986
# INFO:root:[cl 0] Starting segmentation at (53, 129, 86) (zyx)
# INFO:root:[cl 0] Failed: too small: 944
# INFO:root:[cl 0] Starting segmentation at (53, 175, 115) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (54, 56, 184) (zyx)
# INFO:root:[cl 0] Created supervoxel:54  seed(zyx):(54, 56, 184)  size:1725  iters:1
# INFO:root:[cl 0] Starting segmentation at (54, 81, 107) (zyx)
# INFO:root:[cl 0] Created supervoxel:55  seed(zyx):(54, 81, 107)  size:2927  iters:11
# INFO:root:[cl 0] Starting segmentation at (54, 163, 135) (zyx)
# INFO:root:[cl 0] Failed: too small: 151
# INFO:root:[cl 0] Starting segmentation at (55, 68, 102) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (56, 56, 175) (zyx)
# INFO:root:[cl 0] Failed: too small: 492
# INFO:root:[cl 0] Starting segmentation at (57, 57, 116) (zyx)
# INFO:root:[cl 0] Created supervoxel:56  seed(zyx):(57, 57, 116)  size:11594  iters:49
# INFO:root:[cl 0] Starting segmentation at (57, 85, 120) (zyx)
# INFO:root:[cl 0] Failed: too small: 220
# INFO:root:[cl 0] Starting segmentation at (57, 228, 211) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (58, 20, 114) (zyx)
# INFO:root:[cl 0] Created supervoxel:57  seed(zyx):(58, 20, 114)  size:3388  iters:9
# INFO:root:[cl 0] Starting segmentation at (58, 116, 92) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (58, 123, 136) (zyx)
# INFO:root:[cl 0] Failed: too small: 459
# INFO:root:[cl 0] Starting segmentation at (58, 178, 116) (zyx)
# INFO:root:[cl 0] Failed: too small: 368
# INFO:root:[cl 0] Starting segmentation at (59, 109, 120) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (59, 116, 126) (zyx)
# INFO:root:[cl 0] Created supervoxel:58  seed(zyx):(59, 116, 126)  size:1863  iters:1
# INFO:root:[cl 0] Starting segmentation at (59, 117, 98) (zyx)
# INFO:root:[cl 0] Created supervoxel:59  seed(zyx):(59, 117, 98)  size:1319  iters:1
# INFO:root:[cl 0] Starting segmentation at (59, 138, 181) (zyx)
# INFO:root:[cl 0] Created supervoxel:60  seed(zyx):(59, 138, 181)  size:8233  iters:31
# INFO:root:[cl 0] Starting segmentation at (59, 230, 221) (zyx)
# INFO:root:[cl 0] Created supervoxel:61  seed(zyx):(59, 230, 221)  size:2155  iters:1
# INFO:root:[cl 0] Starting segmentation at (60, 98, 86) (zyx)
# INFO:root:[cl 0] Created supervoxel:62  seed(zyx):(60, 98, 86)  size:1272  iters:2
# INFO:root:[cl 0] Starting segmentation at (60, 181, 110) (zyx)
# INFO:root:[cl 0] Failed: too small: 991
# INFO:root:[cl 0] Starting segmentation at (60, 221, 166) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (60, 226, 166) (zyx)
# INFO:root:[cl 0] Created supervoxel:63  seed(zyx):(60, 226, 166)  size:1936  iters:1
# INFO:root:[cl 0] Starting segmentation at (61, 233, 198) (zyx)
# INFO:root:[cl 0] Created supervoxel:64  seed(zyx):(61, 233, 198)  size:3606511  iters:6330
# INFO:root:[cl 0] Starting segmentation at (62, 120, 199) (zyx)
# INFO:root:[cl 0] Failed: too small: 396
# INFO:root:[cl 0] Starting segmentation at (63, 67, 134) (zyx)
# INFO:root:[cl 0] Created supervoxel:65  seed(zyx):(63, 67, 134)  size:2201  iters:9
# INFO:root:[cl 0] Starting segmentation at (63, 104, 113) (zyx)
# INFO:root:[cl 0] Failed: too small: 914
# INFO:root:[cl 0] Starting segmentation at (63, 207, 144) (zyx)
# INFO:root:[cl 0] Created supervoxel:66  seed(zyx):(63, 207, 144)  size:5207  iters:22
# INFO:root:[cl 0] Starting segmentation at (64, 216, 222) (zyx)
# INFO:root:[cl 0] Created supervoxel:67  seed(zyx):(64, 216, 222)  size:9138  iters:13
# INFO:root:[cl 0] Starting segmentation at (65, 23, 197) (zyx)
# INFO:root:[cl 0] Created supervoxel:68  seed(zyx):(65, 23, 197)  size:17766  iters:49
# INFO:root:[cl 0] Starting segmentation at (65, 219, 163) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (65, 226, 160) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (65, 232, 160) (zyx)
# INFO:root:[cl 0] Created supervoxel:69  seed(zyx):(65, 232, 160)  size:42465  iters:123
# INFO:root:[cl 0] Starting segmentation at (66, 36, 181) (zyx)
# INFO:root:[cl 0] Failed: too small: 555
# INFO:root:[cl 0] Starting segmentation at (66, 221, 77) (zyx)
# INFO:root:[cl 0] Created supervoxel:70  seed(zyx):(66, 221, 77)  size:1259  iters:1
# INFO:root:[cl 0] Starting segmentation at (67, 41, 34) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (68, 39, 25) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (68, 54, 16) (zyx)
# INFO:root:[cl 0] Failed: too small: 549
# INFO:root:[cl 0] Starting segmentation at (68, 114, 92) (zyx)
# INFO:root:[cl 0] Failed: too small: 192
# INFO:root:[cl 0] Starting segmentation at (69, 19, 168) (zyx)
# INFO:root:[cl 0] Created supervoxel:71  seed(zyx):(69, 19, 168)  size:2196  iters:7
# INFO:root:[cl 0] Starting segmentation at (69, 172, 154) (zyx)
# INFO:root:[cl 0] Failed: too small: 449
# INFO:root:[cl 0] Starting segmentation at (69, 180, 113) (zyx)
# INFO:root:[cl 0] Failed: too small: 656
# INFO:root:[cl 0] Starting segmentation at (69, 213, 157) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (69, 217, 151) (zyx)
# INFO:root:[cl 0] Created supervoxel:72  seed(zyx):(69, 217, 151)  size:1197  iters:1
# INFO:root:[cl 0] Starting segmentation at (70, 99, 106) (zyx)
# INFO:root:[cl 0] Created supervoxel:73  seed(zyx):(70, 99, 106)  size:2120  iters:1
# INFO:root:[cl 0] Starting segmentation at (70, 218, 130) (zyx)
# INFO:root:[cl 0] Created supervoxel:74  seed(zyx):(70, 218, 130)  size:11898  iters:55
# INFO:root:[cl 0] Starting segmentation at (70, 220, 66) (zyx)
# INFO:root:[cl 0] Created supervoxel:75  seed(zyx):(70, 220, 66)  size:31863  iters:113
# INFO:root:[cl 0] Starting segmentation at (70, 226, 141) (zyx)
# INFO:root:[cl 0] Created supervoxel:76  seed(zyx):(70, 226, 141)  size:1740  iters:1
# INFO:root:[cl 0] Starting segmentation at (71, 108, 56) (zyx)
# INFO:root:[cl 0] Failed: too small: 215
# INFO:root:[cl 0] Starting segmentation at (71, 193, 159) (zyx)
# INFO:root:[cl 0] Created supervoxel:77  seed(zyx):(71, 193, 159)  size:3206  iters:12
# INFO:root:[cl 0] Starting segmentation at (72, 35, 29) (zyx)
# INFO:root:[cl 0] Created supervoxel:78  seed(zyx):(72, 35, 29)  size:4855  iters:12
# INFO:root:[cl 0] Starting segmentation at (72, 204, 162) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (73, 175, 160) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (75, 29, 129) (zyx)
# INFO:root:[cl 0] Failed: too small: 149
# INFO:root:[cl 0] Starting segmentation at (76, 197, 157) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (77, 100, 116) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (77, 125, 208) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (77, 180, 162) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (77, 198, 147) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (78, 93, 97) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (78, 103, 88) (zyx)
# INFO:root:[cl 0] Failed: too small: 287
# INFO:root:[cl 0] Starting segmentation at (78, 114, 93) (zyx)
# INFO:root:[cl 0] Created supervoxel:79  seed(zyx):(78, 114, 93)  size:2316  iters:1
# INFO:root:[cl 0] Starting segmentation at (78, 193, 213) (zyx)
# INFO:root:[cl 0] Failed: too small: 598
# INFO:root:[cl 0] Starting segmentation at (78, 197, 225) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (79, 88, 44) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (79, 169, 163) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (79, 175, 160) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (79, 178, 171) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (79, 188, 165) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (80, 47, 164) (zyx)
# INFO:root:[cl 0] Failed: too small: 344
# INFO:root:[cl 0] Starting segmentation at (80, 90, 63) (zyx)
# INFO:root:[cl 0] Created supervoxel:80  seed(zyx):(80, 90, 63)  size:2930  iters:1
# INFO:root:[cl 0] Starting segmentation at (80, 170, 22) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (80, 188, 175) (zyx)
# INFO:root:[cl 0] Created supervoxel:81  seed(zyx):(80, 188, 175)  size:5248  iters:14
# INFO:root:[cl 0] Starting segmentation at (80, 231, 113) (zyx)
# INFO:root:[cl 0] Created supervoxel:82  seed(zyx):(80, 231, 113)  size:4766  iters:2
# INFO:root:[cl 0] Starting segmentation at (81, 42, 178) (zyx)
# INFO:root:[cl 0] Created supervoxel:83  seed(zyx):(81, 42, 178)  size:1464  iters:1
# INFO:root:[cl 0] Starting segmentation at (81, 174, 16) (zyx)
# INFO:root:[cl 0] Created supervoxel:84  seed(zyx):(81, 174, 16)  size:13786  iters:2
# INFO:root:[cl 0] Starting segmentation at (81, 199, 161) (zyx)
# INFO:root:[cl 0] Created supervoxel:85  seed(zyx):(81, 199, 161)  size:3333  iters:8
# INFO:root:[cl 0] Starting segmentation at (82, 28, 36) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (82, 47, 168) (zyx)
# INFO:root:[cl 0] Failed: too small: 349
# INFO:root:[cl 0] Starting segmentation at (82, 103, 113) (zyx)
# INFO:root:[cl 0] Created supervoxel:86  seed(zyx):(82, 103, 113)  size:2006  iters:1
# INFO:root:[cl 0] Starting segmentation at (82, 112, 213) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (82, 190, 209) (zyx)
# INFO:root:[cl 0] Failed: too small: 514
# INFO:root:[cl 0] Starting segmentation at (83, 191, 201) (zyx)
# INFO:root:[cl 0] Failed: too small: 334
# INFO:root:[cl 0] Starting segmentation at (84, 95, 95) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (84, 105, 212) (zyx)
# INFO:root:[cl 0] Created supervoxel:87  seed(zyx):(84, 105, 212)  size:4201  iters:18
# INFO:root:[cl 0] Starting segmentation at (84, 115, 132) (zyx)
# INFO:root:[cl 0] Created supervoxel:88  seed(zyx):(84, 115, 132)  size:2901  iters:2
# INFO:root:[cl 0] Starting segmentation at (85, 168, 132) (zyx)
# INFO:root:[cl 0] Failed: too small: 339
# INFO:root:[cl 0] Starting segmentation at (85, 170, 144) (zyx)
# INFO:root:[cl 0] Created supervoxel:89  seed(zyx):(85, 170, 144)  size:1320  iters:1
# INFO:root:[cl 0] Starting segmentation at (86, 218, 122) (zyx)
# INFO:root:[cl 0] Failed: too small: 485
# INFO:root:[cl 0] Starting segmentation at (87, 29, 26) (zyx)
# INFO:root:[cl 0] Created supervoxel:90  seed(zyx):(87, 29, 26)  size:35094  iters:29
# INFO:root:[cl 0] Starting segmentation at (87, 124, 158) (zyx)
# INFO:root:[cl 0] Failed: too small: 513
# INFO:root:[cl 0] Starting segmentation at (87, 213, 45) (zyx)
# INFO:root:[cl 0] Created supervoxel:91  seed(zyx):(87, 213, 45)  size:2228  iters:1
# INFO:root:[cl 0] Starting segmentation at (89, 17, 22) (zyx)
# INFO:root:[cl 0] Created supervoxel:92  seed(zyx):(89, 17, 22)  size:1454  iters:9
# INFO:root:[cl 0] Starting segmentation at (89, 85, 225) (zyx)
# INFO:root:[cl 0] Created supervoxel:93  seed(zyx):(89, 85, 225)  size:17612  iters:48
# INFO:root:[cl 0] Starting segmentation at (89, 131, 89) (zyx)
# INFO:root:[cl 0] Created supervoxel:94  seed(zyx):(89, 131, 89)  size:3646  iters:4
# INFO:root:[cl 0] Starting segmentation at (89, 132, 69) (zyx)
# INFO:root:[cl 0] Created supervoxel:95  seed(zyx):(89, 132, 69)  size:30178  iters:120
# INFO:root:[cl 0] Starting segmentation at (89, 132, 227) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (89, 205, 115) (zyx)
# INFO:root:[cl 0] Failed: too small: 572
# INFO:root:[cl 0] Starting segmentation at (90, 137, 222) (zyx)
# INFO:root:[cl 0] Created supervoxel:96  seed(zyx):(90, 137, 222)  size:9155  iters:25
# INFO:root:[cl 0] Starting segmentation at (91, 49, 174) (zyx)
# INFO:root:[cl 0] Created supervoxel:97  seed(zyx):(91, 49, 174)  size:1144  iters:1
# INFO:root:[cl 0] Starting segmentation at (91, 101, 94) (zyx)
# INFO:root:[cl 0] Created supervoxel:98  seed(zyx):(91, 101, 94)  size:3300  iters:2
# INFO:root:[cl 0] Starting segmentation at (91, 163, 114) (zyx)
# INFO:root:[cl 0] Created supervoxel:99  seed(zyx):(91, 163, 114)  size:1311  iters:2
# INFO:root:[cl 0] Starting segmentation at (91, 175, 152) (zyx)
# INFO:root:[cl 0] Created supervoxel:100  seed(zyx):(91, 175, 152)  size:1098  iters:1
# INFO:root:[cl 0] Starting segmentation at (91, 182, 25) (zyx)
# INFO:root:[cl 0] Created supervoxel:101  seed(zyx):(91, 182, 25)  size:1202  iters:1
# INFO:root:[cl 0] Starting segmentation at (91, 184, 211) (zyx)
# INFO:root:[cl 0] Failed: too small: 263
# INFO:root:[cl 0] Starting segmentation at (92, 168, 37) (zyx)
# INFO:root:[cl 0] Failed: too small: 957
# INFO:root:[cl 0] Starting segmentation at (92, 226, 20) (zyx)
# INFO:root:[cl 0] Created supervoxel:102  seed(zyx):(92, 226, 20)  size:172173  iters:442
# INFO:root:[cl 0] Starting segmentation at (93, 24, 222) (zyx)
# INFO:root:[cl 0] Created supervoxel:103  seed(zyx):(93, 24, 222)  size:38618  iters:63
# INFO:root:[cl 0] Starting segmentation at (93, 36, 172) (zyx)
# INFO:root:[cl 0] Created supervoxel:104  seed(zyx):(93, 36, 172)  size:13069  iters:43
# INFO:root:[cl 0] Starting segmentation at (93, 122, 228) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (93, 148, 73) (zyx)
# INFO:root:[cl 0] Created supervoxel:105  seed(zyx):(93, 148, 73)  size:2048  iters:1
# INFO:root:[cl 0] Starting segmentation at (94, 39, 207) (zyx)
# INFO:root:[cl 0] Failed: too small: 215
# INFO:root:[cl 0] Starting segmentation at (94, 98, 198) (zyx)
# INFO:root:[cl 0] Created supervoxel:106  seed(zyx):(94, 98, 198)  size:244993  iters:570
# INFO:root:[cl 0] Starting segmentation at (94, 171, 140) (zyx)
# INFO:root:[cl 0] Failed: too small: 897
# INFO:root:[cl 0] Starting segmentation at (95, 157, 126) (zyx)
# INFO:root:[cl 0] Created supervoxel:107  seed(zyx):(95, 157, 126)  size:1356  iters:1
# INFO:root:[cl 0] Starting segmentation at (95, 163, 139) (zyx)
# INFO:root:[cl 0] Created supervoxel:108  seed(zyx):(95, 163, 139)  size:1358  iters:1
# INFO:root:[cl 0] Starting segmentation at (96, 202, 27) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (97, 120, 207) (zyx)
# INFO:root:[cl 0] Failed: too small: 628
# INFO:root:[cl 0] Starting segmentation at (97, 208, 110) (zyx)
# INFO:root:[cl 0] Failed: too small: 809
# INFO:root:[cl 0] Starting segmentation at (98, 68, 138) (zyx)
# INFO:root:[cl 0] Failed: too small: 727
# INFO:root:[cl 0] Starting segmentation at (98, 73, 65) (zyx)
# INFO:root:[cl 0] Created supervoxel:109  seed(zyx):(98, 73, 65)  size:3054  iters:1
# INFO:root:[cl 0] Starting segmentation at (98, 75, 162) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (98, 93, 219) (zyx)
# INFO:root:[cl 0] Failed: too small: 597
# INFO:root:[cl 0] Starting segmentation at (98, 158, 95) (zyx)
# INFO:root:[cl 0] Created supervoxel:110  seed(zyx):(98, 158, 95)  size:1491  iters:2
# INFO:root:[cl 0] Starting segmentation at (98, 188, 32) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (98, 233, 98) (zyx)
# INFO:root:[cl 0] Created supervoxel:111  seed(zyx):(98, 233, 98)  size:224516  iters:212
# INFO:root:[cl 0] Starting segmentation at (99, 44, 195) (zyx)
# INFO:root:[cl 0] Failed: too small: 973
# INFO:root:[cl 0] Starting segmentation at (99, 79, 173) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (99, 120, 91) (zyx)
# INFO:root:[cl 0] Failed: too small: 413
# INFO:root:[cl 0] Starting segmentation at (99, 128, 81) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (99, 175, 225) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (99, 176, 218) (zyx)
# INFO:root:[cl 0] Created supervoxel:112  seed(zyx):(99, 176, 218)  size:1374  iters:1
# INFO:root:[cl 0] Starting segmentation at (99, 182, 38) (zyx)
# INFO:root:[cl 0] Created supervoxel:113  seed(zyx):(99, 182, 38)  size:3601  iters:10
# INFO:root:[cl 0] Starting segmentation at (99, 195, 22) (zyx)
# INFO:root:[cl 0] Created supervoxel:114  seed(zyx):(99, 195, 22)  size:4875  iters:2
# INFO:root:[cl 0] Starting segmentation at (100, 98, 119) (zyx)
# INFO:root:[cl 0] Failed: too small: 415
# INFO:root:[cl 0] Starting segmentation at (100, 160, 114) (zyx)
# INFO:root:[cl 0] Created supervoxel:115  seed(zyx):(100, 160, 114)  size:78831  iters:223
# INFO:root:[cl 0] Starting segmentation at (100, 230, 113) (zyx)
# INFO:root:[cl 0] Created supervoxel:116  seed(zyx):(100, 230, 113)  size:3905  iters:1
# INFO:root:[cl 0] Starting segmentation at (101, 115, 93) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (101, 159, 195) (zyx)
# INFO:root:[cl 0] Failed: too small: 933
# INFO:root:[cl 0] Starting segmentation at (102, 109, 92) (zyx)
# INFO:root:[cl 0] Created supervoxel:117  seed(zyx):(102, 109, 92)  size:1035  iters:1
# INFO:root:[cl 0] Starting segmentation at (102, 144, 119) (zyx)
# INFO:root:[cl 0] Failed: too small: 656
# INFO:root:[cl 0] Starting segmentation at (103, 74, 153) (zyx)
# INFO:root:[cl 0] Created supervoxel:118  seed(zyx):(103, 74, 153)  size:1349  iters:1
# INFO:root:[cl 0] Starting segmentation at (103, 121, 212) (zyx)
# INFO:root:[cl 0] Failed: too small: 615
# INFO:root:[cl 0] Starting segmentation at (103, 131, 75) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (106, 146, 69) (zyx)
# INFO:root:[cl 0] Created supervoxel:119  seed(zyx):(106, 146, 69)  size:4110  iters:2
# INFO:root:[cl 0] Starting segmentation at (106, 156, 37) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (107, 155, 30) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (107, 165, 31) (zyx)
# INFO:root:[cl 0] Failed: too small: 968
# INFO:root:[cl 0] Starting segmentation at (108, 85, 158) (zyx)
# INFO:root:[cl 0] Failed: too small: 234
# INFO:root:[cl 0] Starting segmentation at (108, 126, 85) (zyx)
# INFO:root:[cl 0] Created supervoxel:120  seed(zyx):(108, 126, 85)  size:1294  iters:2
# INFO:root:[cl 0] Starting segmentation at (108, 151, 26) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (108, 166, 20) (zyx)
# INFO:root:[cl 0] Created supervoxel:121  seed(zyx):(108, 166, 20)  size:27692  iters:32
# INFO:root:[cl 0] Starting segmentation at (109, 85, 114) (zyx)
# INFO:root:[cl 0] Failed: too small: 903
# INFO:root:[cl 0] Starting segmentation at (109, 98, 105) (zyx)
# INFO:root:[cl 0] Created supervoxel:122  seed(zyx):(109, 98, 105)  size:1863  iters:1
# INFO:root:[cl 0] Starting segmentation at (109, 114, 158) (zyx)
# INFO:root:[cl 0] Failed: too small: 213
# INFO:root:[cl 0] Starting segmentation at (110, 92, 141) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (110, 151, 31) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (111, 107, 158) (zyx)
# INFO:root:[cl 0] Failed: too small: 892
# INFO:root:[cl 0] Starting segmentation at (111, 156, 48) (zyx)
# INFO:root:[cl 0] Created supervoxel:123  seed(zyx):(111, 156, 48)  size:3032  iters:2
# INFO:root:[cl 0] Starting segmentation at (112, 77, 150) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (112, 100, 87) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (112, 161, 32) (zyx)
# INFO:root:[cl 0] Created supervoxel:124  seed(zyx):(112, 161, 32)  size:140030  iters:339
# INFO:root:[cl 0] Starting segmentation at (112, 205, 142) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (114, 85, 138) (zyx)
# INFO:root:[cl 0] Created supervoxel:125  seed(zyx):(114, 85, 138)  size:2316  iters:2
# INFO:root:[cl 0] Starting segmentation at (115, 136, 232) (zyx)
# INFO:root:[cl 0] Created supervoxel:126  seed(zyx):(115, 136, 232)  size:1014  iters:2
# INFO:root:[cl 0] Starting segmentation at (115, 220, 17) (zyx)
# INFO:root:[cl 0] Created supervoxel:127  seed(zyx):(115, 220, 17)  size:13359  iters:17
# INFO:root:[cl 0] Starting segmentation at (116, 137, 185) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (116, 144, 188) (zyx)
# INFO:root:[cl 0] Failed: too small: 497
# INFO:root:[cl 0] Starting segmentation at (116, 151, 232) (zyx)
# INFO:root:[cl 0] Created supervoxel:128  seed(zyx):(116, 151, 232)  size:2662  iters:6
# INFO:root:[cl 0] Starting segmentation at (116, 203, 125) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (117, 94, 114) (zyx)
# INFO:root:[cl 0] Created supervoxel:129  seed(zyx):(117, 94, 114)  size:33006  iters:115
# INFO:root:[cl 0] Starting segmentation at (117, 205, 132) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (117, 209, 146) (zyx)
# INFO:root:[cl 0] Created supervoxel:130  seed(zyx):(117, 209, 146)  size:1476  iters:1
# INFO:root:[cl 0] Starting segmentation at (118, 98, 91) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (118, 130, 21) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (118, 152, 217) (zyx)
# INFO:root:[cl 0] Created supervoxel:131  seed(zyx):(118, 152, 217)  size:1749  iters:2
# INFO:root:[cl 0] Starting segmentation at (118, 208, 95) (zyx)
# INFO:root:[cl 0] Failed: too small: 109
# INFO:root:[cl 0] Starting segmentation at (119, 22, 225) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (119, 126, 50) (zyx)
# INFO:root:[cl 0] Failed: too small: 390
# INFO:root:[cl 0] Starting segmentation at (120, 17, 224) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (120, 61, 18) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (120, 86, 112) (zyx)
# INFO:root:[cl 0] Failed: too small: 918
# INFO:root:[cl 0] Starting segmentation at (120, 99, 83) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (120, 141, 194) (zyx)
# INFO:root:[cl 0] Failed: too small: 847
# INFO:root:[cl 0] Starting segmentation at (120, 192, 95) (zyx)
# INFO:root:[cl 0] Failed: too small: 644
# INFO:root:[cl 0] Starting segmentation at (120, 232, 110) (zyx)
# INFO:root:[cl 0] Created supervoxel:132  seed(zyx):(120, 232, 110)  size:2081  iters:2
# INFO:root:[cl 0] Starting segmentation at (121, 27, 233) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (121, 78, 17) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (121, 104, 93) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (122, 81, 149) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (122, 108, 233) (zyx)
# INFO:root:[cl 0] Created supervoxel:133  seed(zyx):(122, 108, 233)  size:1089  iters:1
# INFO:root:[cl 0] Starting segmentation at (122, 201, 95) (zyx)
# INFO:root:[cl 0] Failed: too small: 244
# INFO:root:[cl 0] Starting segmentation at (122, 225, 91) (zyx)
# INFO:root:[cl 0] Failed: too small: 579
# INFO:root:[cl 0] Starting segmentation at (123, 23, 225) (zyx)
# INFO:root:[cl 0] Created supervoxel:134  seed(zyx):(123, 23, 225)  size:5793  iters:9
# INFO:root:[cl 0] Starting segmentation at (123, 79, 115) (zyx)
# INFO:root:[cl 0] Failed: too small: 653
# INFO:root:[cl 0] Starting segmentation at (123, 171, 61) (zyx)
# INFO:root:[cl 0] Created supervoxel:135  seed(zyx):(123, 171, 61)  size:1171  iters:1
# INFO:root:[cl 0] Starting segmentation at (124, 94, 103) (zyx)
# INFO:root:[cl 0] Created supervoxel:136  seed(zyx):(124, 94, 103)  size:7262  iters:36
# INFO:root:[cl 0] Starting segmentation at (125, 85, 100) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (125, 96, 138) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (126, 93, 74) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (126, 98, 86) (zyx)
# INFO:root:[cl 0] Created supervoxel:137  seed(zyx):(126, 98, 86)  size:39048  iters:109
# INFO:root:[cl 0] Starting segmentation at (127, 74, 74) (zyx)
# INFO:root:[cl 0] Failed: too small: 638
# INFO:root:[cl 0] Starting segmentation at (128, 38, 195) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (129, 79, 140) (zyx)
# INFO:root:[cl 0] Created supervoxel:138  seed(zyx):(129, 79, 140)  size:5013  iters:22
# INFO:root:[cl 0] Starting segmentation at (130, 25, 200) (zyx)
# INFO:root:[cl 0] Created supervoxel:139  seed(zyx):(130, 25, 200)  size:1594  iters:1
# INFO:root:[cl 0] Starting segmentation at (130, 70, 90) (zyx)
# INFO:root:[cl 0] Created supervoxel:140  seed(zyx):(130, 70, 90)  size:50399  iters:137
# INFO:root:[cl 0] Starting segmentation at (130, 89, 167) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (130, 171, 51) (zyx)
# INFO:root:[cl 0] Created supervoxel:141  seed(zyx):(130, 171, 51)  size:59205  iters:126
# INFO:root:[cl 0] Starting segmentation at (131, 182, 37) (zyx)
# INFO:root:[cl 0] Failed: too small: 563
# INFO:root:[cl 0] Starting segmentation at (133, 29, 221) (zyx)
# INFO:root:[cl 0] Created supervoxel:142  seed(zyx):(133, 29, 221)  size:20416  iters:67
# INFO:root:[cl 0] Starting segmentation at (133, 91, 124) (zyx)
# INFO:root:[cl 0] Failed: too small: 214
# INFO:root:[cl 0] Starting segmentation at (133, 151, 24) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (133, 223, 93) (zyx)
# INFO:root:[cl 0] Failed: too small: 496
# INFO:root:[cl 0] Starting segmentation at (134, 26, 16) (zyx)
# INFO:root:[cl 0] Created supervoxel:143  seed(zyx):(134, 26, 16)  size:10698  iters:12
# INFO:root:[cl 0] Starting segmentation at (134, 61, 138) (zyx)
# INFO:root:[cl 0] Created supervoxel:144  seed(zyx):(134, 61, 138)  size:1826  iters:8
# INFO:root:[cl 0] Starting segmentation at (134, 64, 122) (zyx)
# INFO:root:[cl 0] Failed: too small: 793
# INFO:root:[cl 0] Starting segmentation at (134, 157, 60) (zyx)
# INFO:root:[cl 0] Failed: too small: 166
# INFO:root:[cl 0] Starting segmentation at (134, 223, 105) (zyx)
# INFO:root:[cl 0] Created supervoxel:145  seed(zyx):(134, 223, 105)  size:1425  iters:1
# INFO:root:[cl 0] Starting segmentation at (135, 76, 64) (zyx)
# INFO:root:[cl 0] Failed: too small: 970
# INFO:root:[cl 0] Starting segmentation at (135, 182, 38) (zyx)
# INFO:root:[cl 0] Failed: too small: 756
# INFO:root:[cl 0] Starting segmentation at (135, 229, 26) (zyx)
# INFO:root:[cl 0] Created supervoxel:146  seed(zyx):(135, 229, 26)  size:134755  iters:290
# INFO:root:[cl 0] Starting segmentation at (136, 48, 28) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (136, 130, 146) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (136, 205, 46) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (137, 69, 151) (zyx)
# INFO:root:[cl 0] Failed: too small: 930
# INFO:root:[cl 0] Starting segmentation at (137, 95, 232) (zyx)
# INFO:root:[cl 0] Created supervoxel:147  seed(zyx):(137, 95, 232)  size:43675  iters:142
# INFO:root:[cl 0] Starting segmentation at (137, 178, 16) (zyx)
# INFO:root:[cl 0] Created supervoxel:148  seed(zyx):(137, 178, 16)  size:1421  iters:4
# INFO:root:[cl 0] Starting segmentation at (138, 55, 35) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (138, 146, 233) (zyx)
# INFO:root:[cl 0] Created supervoxel:149  seed(zyx):(138, 146, 233)  size:3401  iters:2
# INFO:root:[cl 0] Starting segmentation at (138, 171, 19) (zyx)
# INFO:root:[cl 0] Created supervoxel:150  seed(zyx):(138, 171, 19)  size:2597  iters:5
# INFO:root:[cl 0] Starting segmentation at (138, 218, 55) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (139, 42, 201) (zyx)
# INFO:root:[cl 0] Created supervoxel:151  seed(zyx):(139, 42, 201)  size:1384  iters:1
# INFO:root:[cl 0] Starting segmentation at (139, 77, 132) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (139, 186, 85) (zyx)
# INFO:root:[cl 0] Created supervoxel:152  seed(zyx):(139, 186, 85)  size:1126  iters:1
# INFO:root:[cl 0] Starting segmentation at (139, 220, 95) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (139, 228, 49) (zyx)
# INFO:root:[cl 0] Failed: too small: 532
# INFO:root:[cl 0] Starting segmentation at (140, 153, 27) (zyx)
# INFO:root:[cl 0] Failed: too small: 188
# INFO:root:[cl 0] Starting segmentation at (140, 231, 77) (zyx)
# INFO:root:[cl 0] Failed: too small: 473
# INFO:root:[cl 0] Starting segmentation at (140, 233, 50) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (141, 61, 44) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (141, 159, 48) (zyx)
# INFO:root:[cl 0] Failed: too small: 522
# INFO:root:[cl 0] Starting segmentation at (141, 233, 16) (zyx)
# INFO:root:[cl 0] Failed: too small: 398
# INFO:root:[cl 0] Starting segmentation at (142, 48, 228) (zyx)
# INFO:root:[cl 0] Failed: too small: 539
# INFO:root:[cl 0] Starting segmentation at (142, 71, 127) (zyx)
# INFO:root:[cl 0] Failed: too small: 226
# INFO:root:[cl 0] Starting segmentation at (142, 75, 89) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (142, 77, 121) (zyx)
# INFO:root:[cl 0] Created supervoxel:153  seed(zyx):(142, 77, 121)  size:2268  iters:13
# INFO:root:[cl 0] Starting segmentation at (142, 129, 143) (zyx)
# INFO:root:[cl 0] Created supervoxel:154  seed(zyx):(142, 129, 143)  size:1862  iters:1
# INFO:root:[cl 0] Starting segmentation at (142, 160, 20) (zyx)
# INFO:root:[cl 0] Failed: too small: 211
# INFO:root:[cl 0] Starting segmentation at (142, 165, 39) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (143, 42, 21) (zyx)
# INFO:root:[cl 0] Created supervoxel:155  seed(zyx):(143, 42, 21)  size:17379  iters:58
# INFO:root:[cl 0] Starting segmentation at (143, 66, 55) (zyx)
# INFO:root:[cl 0] Created supervoxel:156  seed(zyx):(143, 66, 55)  size:2337  iters:2
# INFO:root:[cl 0] Starting segmentation at (143, 68, 152) (zyx)
# INFO:root:[cl 0] Created supervoxel:157  seed(zyx):(143, 68, 152)  size:1263  iters:2
# INFO:root:[cl 0] Starting segmentation at (143, 81, 176) (zyx)
# INFO:root:[cl 0] Created supervoxel:158  seed(zyx):(143, 81, 176)  size:46696  iters:175
# INFO:root:[cl 0] Starting segmentation at (143, 187, 22) (zyx)
# INFO:root:[cl 0] Failed: too small: 324
# INFO:root:[cl 0] Starting segmentation at (143, 228, 66) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (144, 224, 59) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (145, 71, 105) (zyx)
# INFO:root:[cl 0] Created supervoxel:159  seed(zyx):(145, 71, 105)  size:48906  iters:127
# INFO:root:[cl 0] Starting segmentation at (145, 200, 21) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (145, 209, 55) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (146, 69, 95) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (147, 228, 111) (zyx)
# INFO:root:[cl 0] Failed: too small: 479
# INFO:root:[cl 0] Starting segmentation at (148, 202, 53) (zyx)
# INFO:root:[cl 0] Created supervoxel:160  seed(zyx):(148, 202, 53)  size:12876  iters:32
# INFO:root:[cl 0] Starting segmentation at (148, 227, 70) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (148, 233, 113) (zyx)
# INFO:root:[cl 0] Created supervoxel:161  seed(zyx):(148, 233, 113)  size:3273  iters:1
# INFO:root:[cl 0] Starting segmentation at (149, 35, 232) (zyx)
# INFO:root:[cl 0] Created supervoxel:162  seed(zyx):(149, 35, 232)  size:12213  iters:15
# INFO:root:[cl 0] Starting segmentation at (149, 123, 227) (zyx)
# INFO:root:[cl 0] Created supervoxel:163  seed(zyx):(149, 123, 227)  size:1337  iters:3
# INFO:root:[cl 0] Starting segmentation at (149, 181, 19) (zyx)
# INFO:root:[cl 0] Created supervoxel:164  seed(zyx):(149, 181, 19)  size:5646  iters:1
# INFO:root:[cl 0] Starting segmentation at (149, 220, 91) (zyx)
# INFO:root:[cl 0] Failed: too small: 330
# INFO:root:[cl 0] Starting segmentation at (149, 232, 21) (zyx)
# INFO:root:[cl 0] Failed: too small: 736
# INFO:root:[cl 0] Starting segmentation at (150, 121, 157) (zyx)
# INFO:root:[cl 0] Created supervoxel:165  seed(zyx):(150, 121, 157)  size:10294  iters:33
# INFO:root:[cl 0] Starting segmentation at (151, 142, 151) (zyx)
# INFO:root:[cl 0] Failed: too small: 530
# INFO:root:[cl 0] Starting segmentation at (152, 28, 123) (zyx)
# INFO:root:[cl 0] Failed: too small: 998
# INFO:root:[cl 0] Starting segmentation at (152, 83, 229) (zyx)
# INFO:root:[cl 0] Created supervoxel:166  seed(zyx):(152, 83, 229)  size:1531  iters:1
# INFO:root:[cl 0] Starting segmentation at (152, 226, 66) (zyx)
# INFO:root:[cl 0] Created supervoxel:167  seed(zyx):(152, 226, 66)  size:28856  iters:85
# INFO:root:[cl 0] Starting segmentation at (153, 50, 121) (zyx)
# INFO:root:[cl 0] Created supervoxel:168  seed(zyx):(153, 50, 121)  size:39934  iters:130
# INFO:root:[cl 0] Starting segmentation at (153, 52, 80) (zyx)
# INFO:root:[cl 0] Created supervoxel:169  seed(zyx):(153, 52, 80)  size:1081  iters:1
# INFO:root:[cl 0] Starting segmentation at (153, 224, 20) (zyx)
# INFO:root:[cl 0] Created supervoxel:170  seed(zyx):(153, 224, 20)  size:2344  iters:1
# INFO:root:[cl 0] Starting segmentation at (154, 138, 159) (zyx)
# INFO:root:[cl 0] Created supervoxel:171  seed(zyx):(154, 138, 159)  size:1579  iters:3
# INFO:root:[cl 0] Starting segmentation at (155, 218, 16) (zyx)
# INFO:root:[cl 0] Created supervoxel:172  seed(zyx):(155, 218, 16)  size:28386  iters:95
# INFO:root:[cl 0] Starting segmentation at (156, 58, 95) (zyx)
# INFO:root:[cl 0] Created supervoxel:173  seed(zyx):(156, 58, 95)  size:16293  iters:62
# INFO:root:[cl 0] Starting segmentation at (157, 44, 196) (zyx)
# INFO:root:[cl 0] Created supervoxel:174  seed(zyx):(157, 44, 196)  size:12975  iters:41
# INFO:root:[cl 0] Starting segmentation at (157, 219, 106) (zyx)
# INFO:root:[cl 0] Created supervoxel:175  seed(zyx):(157, 219, 106)  size:1057  iters:1
# INFO:root:[cl 0] Starting segmentation at (157, 233, 35) (zyx)
# INFO:root:[cl 0] Created supervoxel:176  seed(zyx):(157, 233, 35)  size:69227  iters:118
# INFO:root:[cl 0] Starting segmentation at (158, 48, 223) (zyx)
# INFO:root:[cl 0] Failed: too small: 114
# INFO:root:[cl 0] Starting segmentation at (158, 64, 157) (zyx)
# INFO:root:[cl 0] Failed: too small: 557
# INFO:root:[cl 0] Starting segmentation at (158, 73, 155) (zyx)
# INFO:root:[cl 0] Created supervoxel:177  seed(zyx):(158, 73, 155)  size:12122  iters:63
# INFO:root:[cl 0] Starting segmentation at (158, 228, 204) (zyx)
# INFO:root:[cl 0] Created supervoxel:178  seed(zyx):(158, 228, 204)  size:12578  iters:27
# INFO:root:[cl 0] Starting segmentation at (161, 48, 233) (zyx)
# INFO:root:[cl 0] Created supervoxel:179  seed(zyx):(161, 48, 233)  size:25183  iters:24
# INFO:root:[cl 0] Starting segmentation at (161, 224, 220) (zyx)
# INFO:root:[cl 0] Failed: too small: 792
# INFO:root:[cl 0] Starting segmentation at (161, 230, 18) (zyx)
# INFO:root:[cl 0] Created supervoxel:180  seed(zyx):(161, 230, 18)  size:29756  iters:81
# INFO:root:[cl 0] Starting segmentation at (163, 197, 36) (zyx)
# INFO:root:[cl 0] Failed: too small: 366
# INFO:root:[cl 0] Starting segmentation at (164, 94, 229) (zyx)
# INFO:root:[cl 0] Created supervoxel:181  seed(zyx):(164, 94, 229)  size:3322  iters:12
# INFO:root:[cl 0] Starting segmentation at (164, 176, 71) (zyx)
# INFO:root:[cl 0] Failed: too small: 38
# INFO:root:[cl 0] Starting segmentation at (167, 195, 42) (zyx)
# INFO:root:[cl 0] Failed: too small: 443
# INFO:root:[cl 0] Starting segmentation at (167, 218, 20) (zyx)
# ...
# INFO:root:[cl 0] Created supervoxel:187  seed(zyx):(179, 232, 230)  size:151133  iters:136
# INFO:root:[cl 0] Starting segmentation at (180, 54, 168) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (181, 34, 28) (zyx)
# INFO:root:[cl 0] Failed: too small: 400
# INFO:root:[cl 0] Starting segmentation at (181, 233, 186) (zyx)
# INFO:root:[cl 0] Created supervoxel:188  seed(zyx):(181, 233, 186)  size:10177  iters:2
# INFO:root:[cl 0] Starting segmentation at (182, 38, 231) (zyx)
# INFO:root:[cl 0] Created supervoxel:189  seed(zyx):(182, 38, 231)  size:11200  iters:16
# INFO:root:[cl 0] Starting segmentation at (182, 41, 171) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (184, 35, 170) (zyx)
# INFO:root:[cl 0] Created supervoxel:190  seed(zyx):(184, 35, 170)  size:9603  iters:26
# INFO:root:[cl 0] Starting segmentation at (184, 55, 154) (zyx)
# INFO:root:[cl 0] Created supervoxel:191  seed(zyx):(184, 55, 154)  size:1596  iters:4
# INFO:root:[cl 0] Starting segmentation at (185, 186, 51) (zyx)
# INFO:root:[cl 0] Failed: too small: 901
# INFO:root:[cl 0] Starting segmentation at (189, 28, 197) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (189, 50, 204) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (190, 182, 61) (zyx)
# INFO:root:[cl 0] Failed: too small: 290
# INFO:root:[cl 0] Starting segmentation at (190, 214, 208) (zyx)
# INFO:root:[cl 0] Created supervoxel:192  seed(zyx):(190, 214, 208)  size:1521  iters:1
# INFO:root:[cl 0] Starting segmentation at (191, 56, 223) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (192, 40, 200) (zyx)
# INFO:root:[cl 0] Created supervoxel:193  seed(zyx):(192, 40, 200)  size:9841  iters:3
# INFO:root:[cl 0] Starting segmentation at (192, 66, 159) (zyx)
# INFO:root:[cl 0] Failed: too small: 131
# INFO:root:[cl 0] Starting segmentation at (192, 173, 99) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (193, 204, 230) (zyx)
# INFO:root:[cl 0] Created supervoxel:194  seed(zyx):(193, 204, 230)  size:6288  iters:1
# INFO:root:[cl 0] Starting segmentation at (193, 232, 128) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (194, 50, 218) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (194, 224, 24) (zyx)
# INFO:root:[cl 0] Created supervoxel:195  seed(zyx):(194, 224, 24)  size:91348  iters:48
# INFO:root:[cl 0] Starting segmentation at (194, 233, 120) (zyx)
# INFO:root:[cl 0] Created supervoxel:196  seed(zyx):(194, 233, 120)  size:16742  iters:41
# INFO:root:[cl 0] Starting segmentation at (195, 51, 171) (zyx)
# INFO:root:[cl 0] Failed: too small: 558
# INFO:root:[cl 0] Starting segmentation at (195, 56, 222) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (195, 68, 230) (zyx)
# INFO:root:[cl 0] Created supervoxel:197  seed(zyx):(195, 68, 230)  size:32599  iters:71
# INFO:root:[cl 0] Starting segmentation at (195, 210, 211) (zyx)
# INFO:root:[cl 0] Created supervoxel:198  seed(zyx):(195, 210, 211)  size:2443  iters:1
# INFO:root:[cl 0] Starting segmentation at (196, 29, 179) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (196, 68, 169) (zyx)
# INFO:root:[cl 0] Failed: too small: 301
# INFO:root:[cl 0] Starting segmentation at (196, 209, 59) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (196, 232, 169) (zyx)
# INFO:root:[cl 0] Created supervoxel:199  seed(zyx):(196, 232, 169)  size:30981  iters:60
# INFO:root:[cl 0] Starting segmentation at (197, 20, 189) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (197, 25, 173) (zyx)
# INFO:root:[cl 0] Failed: too small: 950
# INFO:root:[cl 0] Starting segmentation at (197, 63, 123) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (198, 17, 93) (zyx)
# INFO:root:[cl 0] Created supervoxel:200  seed(zyx):(198, 17, 93)  size:219098  iters:206
# INFO:root:[cl 0] Starting segmentation at (198, 19, 196) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (198, 28, 166) (zyx)
# INFO:root:[cl 0] Created supervoxel:201  seed(zyx):(198, 28, 166)  size:1786  iters:2
# INFO:root:[cl 0] Starting segmentation at (198, 64, 93) (zyx)
# INFO:root:[cl 0] Created supervoxel:202  seed(zyx):(198, 64, 93)  size:1314  iters:2
# INFO:root:[cl 0] Starting segmentation at (198, 160, 20) (zyx)
# INFO:root:[cl 0] Created supervoxel:203  seed(zyx):(198, 160, 20)  size:15520  iters:16
# INFO:root:[cl 0] Starting segmentation at (199, 46, 51) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (199, 133, 17) (zyx)
# INFO:root:[cl 0] Created supervoxel:204  seed(zyx):(199, 133, 17)  size:20752  iters:29
# INFO:root:[cl 0] Starting segmentation at (199, 169, 102) (zyx)
# INFO:root:[cl 0] Failed: too small: 292
# INFO:root:[cl 0] Starting segmentation at (200, 25, 18) (zyx)
# INFO:root:[cl 0] Created supervoxel:205  seed(zyx):(200, 25, 18)  size:5829  iters:25
# INFO:root:[cl 0] Starting segmentation at (200, 170, 108) (zyx)
# INFO:root:[cl 0] Failed: too small: 692
# INFO:root:[cl 0] Starting segmentation at (201, 62, 172) (zyx)
# INFO:root:[cl 0] Created supervoxel:206  seed(zyx):(201, 62, 172)  size:1727  iters:1
# INFO:root:[cl 0] Starting segmentation at (201, 65, 181) (zyx)
# INFO:root:[cl 0] Created supervoxel:207  seed(zyx):(201, 65, 181)  size:21227  iters:76
# INFO:root:[cl 0] Starting segmentation at (202, 32, 136) (zyx)
# INFO:root:[cl 0] Failed: too small: 888
# INFO:root:[cl 0] Starting segmentation at (203, 28, 193) (zyx)
# INFO:root:[cl 0] Created supervoxel:208  seed(zyx):(203, 28, 193)  size:1556  iters:1
# INFO:root:[cl 0] Starting segmentation at (203, 30, 116) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (203, 31, 122) (zyx)
# INFO:root:[cl 0] Created supervoxel:209  seed(zyx):(203, 31, 122)  size:3900  iters:1
# INFO:root:[cl 0] Starting segmentation at (203, 33, 143) (zyx)
# INFO:root:[cl 0] Failed: too small: 548
# INFO:root:[cl 0] Starting segmentation at (203, 35, 163) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (203, 44, 168) (zyx)
# INFO:root:[cl 0] Created supervoxel:210  seed(zyx):(203, 44, 168)  size:2928  iters:2
# INFO:root:[cl 0] Starting segmentation at (203, 206, 61) (zyx)
# INFO:root:[cl 0] Failed: too small: 504
# INFO:root:[cl 0] Starting segmentation at (204, 16, 25) (zyx)
# INFO:root:[cl 0] Created supervoxel:211  seed(zyx):(204, 16, 25)  size:8067  iters:3
# INFO:root:[cl 0] Starting segmentation at (204, 26, 181) (zyx)
# INFO:root:[cl 0] Created supervoxel:212  seed(zyx):(204, 26, 181)  size:13859  iters:33
# INFO:root:[cl 0] Starting segmentation at (205, 47, 229) (zyx)
# INFO:root:[cl 0] Created supervoxel:213  seed(zyx):(205, 47, 229)  size:80202  iters:112
# INFO:root:[cl 0] Starting segmentation at (205, 67, 157) (zyx)
# INFO:root:[cl 0] Created supervoxel:214  seed(zyx):(205, 67, 157)  size:13606  iters:46
# INFO:root:[cl 0] Starting segmentation at (206, 146, 22) (zyx)
# INFO:root:[cl 0] Created supervoxel:215  seed(zyx):(206, 146, 22)  size:7346  iters:8
# INFO:root:[cl 0] Starting segmentation at (207, 45, 141) (zyx)
# INFO:root:[cl 0] Created supervoxel:216  seed(zyx):(207, 45, 141)  size:1811  iters:1
# INFO:root:[cl 0] Starting segmentation at (207, 51, 207) (zyx)
# INFO:root:[cl 0] Created supervoxel:217  seed(zyx):(207, 51, 207)  size:1765  iters:1
# INFO:root:[cl 0] Starting segmentation at (207, 75, 127) (zyx)
# INFO:root:[cl 0] Failed: too small: 206
# INFO:root:[cl 0] Starting segmentation at (207, 232, 131) (zyx)
# INFO:root:[cl 0] Created supervoxel:218  seed(zyx):(207, 232, 131)  size:16533  iters:27
# INFO:root:[cl 0] Starting segmentation at (208, 22, 205) (zyx)
# INFO:root:[cl 0] Created supervoxel:219  seed(zyx):(208, 22, 205)  size:2421  iters:1
# INFO:root:[cl 0] Starting segmentation at (208, 170, 116) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (208, 175, 87) (zyx)
# INFO:root:[cl 0] Failed: too small: 433
# INFO:root:[cl 0] Starting segmentation at (212, 66, 122) (zyx)
# INFO:root:[cl 0] Created supervoxel:220  seed(zyx):(212, 66, 122)  size:20120  iters:53
# INFO:root:[cl 0] Starting segmentation at (212, 173, 68) (zyx)
# INFO:root:[cl 0] Failed: too small: 290
# INFO:root:[cl 0] Starting segmentation at (213, 19, 62) (zyx)
# INFO:root:[cl 0] Created supervoxel:221  seed(zyx):(213, 19, 62)  size:189744  iters:134
# INFO:root:[cl 0] Starting segmentation at (213, 34, 206) (zyx)
# INFO:root:[cl 0] Created supervoxel:222  seed(zyx):(213, 34, 206)  size:58776  iters:63
# INFO:root:[cl 0] Starting segmentation at (213, 45, 48) (zyx)
# INFO:root:[cl 0] Failed: too small: 198
# INFO:root:[cl 0] Starting segmentation at (213, 54, 167) (zyx)
# INFO:root:[cl 0] Created supervoxel:223  seed(zyx):(213, 54, 167)  size:7303  iters:34
# INFO:root:[cl 0] Starting segmentation at (215, 51, 150) (zyx)
# INFO:root:[cl 0] Failed: too small: 333
# INFO:root:[cl 0] Starting segmentation at (216, 132, 16) (zyx)
# INFO:root:[cl 0] Created supervoxel:224  seed(zyx):(216, 132, 16)  size:19339  iters:13
# INFO:root:[cl 0] Starting segmentation at (216, 198, 69) (zyx)
# INFO:root:[cl 0] Failed: too small: 213
# INFO:root:[cl 0] Starting segmentation at (216, 226, 126) (zyx)
# INFO:root:[cl 0] Created supervoxel:225  seed(zyx):(216, 226, 126)  size:17433  iters:20
# INFO:root:[cl 0] Starting segmentation at (218, 108, 233) (zyx)
# INFO:root:[cl 0] Created supervoxel:226  seed(zyx):(218, 108, 233)  size:12355  iters:2
# INFO:root:[cl 0] Starting segmentation at (218, 154, 111) (zyx)
# INFO:root:[cl 0] Created supervoxel:227  seed(zyx):(218, 154, 111)  size:1352  iters:1
# INFO:root:[cl 0] Starting segmentation at (219, 53, 146) (zyx)
# INFO:root:[cl 0] Created supervoxel:228  seed(zyx):(219, 53, 146)  size:1188  iters:2
# INFO:root:[cl 0] Starting segmentation at (220, 29, 35) (zyx)
# INFO:root:[cl 0] Created supervoxel:229  seed(zyx):(220, 29, 35)  size:14912  iters:39
# INFO:root:[cl 0] Starting segmentation at (220, 59, 174) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (220, 64, 176) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (220, 64, 181) (zyx)
# INFO:root:[cl 0] Failed: too small: 569
# INFO:root:[cl 0] Starting segmentation at (220, 66, 134) (zyx)
# INFO:root:[cl 0] Created supervoxel:230  seed(zyx):(220, 66, 134)  size:1256  iters:2
# INFO:root:[cl 0] Starting segmentation at (220, 213, 158) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (221, 83, 180) (zyx)
# INFO:root:[cl 0] Created supervoxel:231  seed(zyx):(221, 83, 180)  size:2864  iters:1
# INFO:root:[cl 0] Starting segmentation at (221, 209, 164) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (222, 82, 147) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (222, 160, 82) (zyx)
# INFO:root:[cl 0] Created supervoxel:232  seed(zyx):(222, 160, 82)  size:24122  iters:36
# INFO:root:[cl 0] Starting segmentation at (222, 214, 133) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (222, 229, 159) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (223, 41, 107) (zyx)
# INFO:root:[cl 0] Failed: too small: 481
# INFO:root:[cl 0] Starting segmentation at (223, 57, 164) (zyx)
# INFO:root:[cl 0] Failed: too small: 721
# INFO:root:[cl 0] Starting segmentation at (223, 200, 189) (zyx)
# INFO:root:[cl 0] Created supervoxel:233  seed(zyx):(223, 200, 189)  size:6879  iters:2
# INFO:root:[cl 0] Starting segmentation at (223, 230, 128) (zyx)
# INFO:root:[cl 0] Created supervoxel:234  seed(zyx):(223, 230, 128)  size:8206  iters:2
# INFO:root:[cl 0] Starting segmentation at (224, 43, 119) (zyx)
# INFO:root:[cl 0] Created supervoxel:235  seed(zyx):(224, 43, 119)  size:4523  iters:4
# INFO:root:[cl 0] Starting segmentation at (224, 59, 170) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (224, 88, 204) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (224, 123, 42) (zyx)
# INFO:root:[cl 0] Created supervoxel:236  seed(zyx):(224, 123, 42)  size:19333  iters:30
# INFO:root:[cl 0] Starting segmentation at (224, 223, 62) (zyx)
# INFO:root:[cl 0] Created supervoxel:237  seed(zyx):(224, 223, 62)  size:22197  iters:4
# INFO:root:[cl 0] Starting segmentation at (224, 230, 146) (zyx)
# INFO:root:[cl 0] Created supervoxel:238  seed(zyx):(224, 230, 146)  size:6096  iters:12
# INFO:root:[cl 0] Starting segmentation at (225, 90, 218) (zyx)
# INFO:root:[cl 0] Created supervoxel:239  seed(zyx):(225, 90, 218)  size:1582  iters:2
# INFO:root:[cl 0] Starting segmentation at (225, 101, 40) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (225, 128, 224) (zyx)
# INFO:root:[cl 0] Created supervoxel:240  seed(zyx):(225, 128, 224)  size:8603  iters:2
# INFO:root:[cl 0] Starting segmentation at (226, 59, 151) (zyx)
# INFO:root:[cl 0] Created supervoxel:241  seed(zyx):(226, 59, 151)  size:2608  iters:1
# INFO:root:[cl 0] Starting segmentation at (226, 77, 142) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (226, 214, 163) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (227, 61, 85) (zyx)
# INFO:root:[cl 0] Failed: too small: 514
# INFO:root:[cl 0] Starting segmentation at (227, 212, 179) (zyx)
# INFO:root:[cl 0] Created supervoxel:242  seed(zyx):(227, 212, 179)  size:4291  iters:8
# INFO:root:[cl 0] Starting segmentation at (228, 96, 154) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (228, 194, 223) (zyx)
# INFO:root:[cl 0] Created supervoxel:243  seed(zyx):(228, 194, 223)  size:9487  iters:14
# INFO:root:[cl 0] Starting segmentation at (228, 195, 27) (zyx)
# INFO:root:[cl 0] Failed: too small: 933
# INFO:root:[cl 0] Starting segmentation at (228, 230, 138) (zyx)
# INFO:root:[cl 0] Created supervoxel:244  seed(zyx):(228, 230, 138)  size:41789  iters:24
# INFO:root:[cl 0] Starting segmentation at (229, 88, 154) (zyx)
# INFO:root:[cl 0] Created supervoxel:245  seed(zyx):(229, 88, 154)  size:2544  iters:10
# INFO:root:[cl 0] Starting segmentation at (229, 163, 230) (zyx)
# INFO:root:[cl 0] Created supervoxel:246  seed(zyx):(229, 163, 230)  size:8553  iters:2
# INFO:root:[cl 0] Starting segmentation at (229, 168, 75) (zyx)
# INFO:root:[cl 0] Failed: too small: 131
# INFO:root:[cl 0] Starting segmentation at (229, 174, 200) (zyx)
# INFO:root:[cl 0] Created supervoxel:247  seed(zyx):(229, 174, 200)  size:1747  iters:1
# INFO:root:[cl 0] Starting segmentation at (230, 101, 202) (zyx)
# INFO:root:[cl 0] Created supervoxel:248  seed(zyx):(230, 101, 202)  size:4712  iters:1
# INFO:root:[cl 0] Starting segmentation at (231, 61, 95) (zyx)
# INFO:root:[cl 0] Created supervoxel:249  seed(zyx):(231, 61, 95)  size:3737  iters:2
# INFO:root:[cl 0] Starting segmentation at (231, 65, 126) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (231, 150, 20) (zyx)
# INFO:root:[cl 0] Created supervoxel:250  seed(zyx):(231, 150, 20)  size:4139  iters:1
# INFO:root:[cl 0] Starting segmentation at (232, 68, 132) (zyx)
# INFO:root:[cl 0] Failed: weak seed
# INFO:root:[cl 0] Starting segmentation at (232, 85, 172) (zyx)
# INFO:root:[cl 0] Created supervoxel:251  seed(zyx):(232, 85, 172)  size:2448  iters:1
# INFO:root:[cl 0] Starting segmentation at (233, 131, 201) (zyx)
# INFO:root:[cl 0] Created supervoxel:252  seed(zyx):(233, 131, 201)  size:17794  iters:2
# INFO:root:[cl 0] Starting segmentation at (233, 210, 152) (zyx)
# INFO:root:[cl 0] Created supervoxel:253  seed(zyx):(233, 210, 152)  size:8070  iters:2
# INFO:root:[cl 0] Starting segmentation at (233, 233, 232) (zyx)
# INFO:root:[cl 0] Created supervoxel:254  seed(zyx):(233, 233, 232)  size:17444  iters:1
# INFO:root:[cl 0] Segmentation done.
# INFO:root:Deregistering client 0
# INFO:root:client 0 terminating
